# %% [markdown]
# # **(ADD THE NOTEBOOK NAME HERE)**

# %% [markdown]
# ## Objectives
#
# - Check the contents of the raw credit card customer dataset
# - Explore the data to check data types, summary statistics and basic patterns in the dataset
# - Clean the data by handling missing data, duplicates and drop any unnecessary columns
# - Save the cleaned data for data visualising
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/nav/Desktop/Project 1/credit_card_analysis/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/nav/Desktop/Project 1/credit_card_analysis'

# %% [markdown]
# # Import Libraries

# %%
#import the the libraries i will be using for this project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content i will be importing my dataset in

# %% [markdown]
# # Loading and checking the Dataset
# In section 1 i loaded in the BankChurners dataset and looked at the first 5 rows using df.head()

# %%
df = pd.read_csv('Dataset/RawData/BankChurners.csv')
df.head() #this is showing the first 5 rows of the dataset
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# # Dataframe shape
# I've looked at the size and shape of the dataframe using the df.shape function. This shows me that there is 10,127 rows and 23 columns in the dataset

# %%
#checking the shape of the dataset it will show the number of rows and columns in the dataset
df.shape
#it shows that the dataset has 10127 rows and 23 columns
# Out:
# (10127, 23)

# %% [markdown]
# # Data structure
# I've looked at the stucture of the dataset using .columns, .dtypes and .info()
#
# .columns shows me the names of the columns in the dataet and i will be able to see if i need to remove any columns that will not be useful in the analysis
#
# .dtypes shows me the datatype of each columns and are used to check that numeric values like 'Customer_age', 'Credit_Limit' are stored as integers or floats, and to see if categorical values like 'Gender and "Education_Level were stored correctly
#
# .info() gives a summary of the dataset which shows if there are any non-null values in each column. In this data it shows that there are no missing values therefore no cleaning for missing values will have to be done. it also states that there are 7 float columns, 10 integar columns, and 5 object columns.

# %%
# Checking the names of the columns in the dataset
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
# Checking the data types of each column in the dataset
df.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
# Checking the data types of each column and if there are any null values in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# # Statistics for key columns
# using the .describe allows you to get numerical summary of the columns selected. The function gives you a count, mean, standard deviation(std), min, 25%, 50%, 75% and max value. It is useful to see the average and range of values and can help spot any outliers or weird values
#
# The values have been rounded to 2 decimal places using .round(2) to make them easier to read.

# %%
# Checks statistical summary of the 'months on book' and 'credit limit' columns in the dataset
df[['Months_on_book', 'Credit_Limit']].describe().round(2) # Rounded to 2 decimal places for better readability.
# Out:
#        Months_on_book  Credit_Limit
# count        10127.00      10127.00
# mean            35.93       8631.95
# std              7.99       9088.78
# min             13.00       1438.30
# 25%             31.00       2555.00
# 50%             36.00       4549.00
# 75%             40.00      11067.50
# max             56.00      34516.00

# %% [markdown]
# Using the .unique function allows you to see the all the different values in a column. it will list all the unique values once without duplicates. It will show what categories are in the selected column. The output shows 'Existing Customer' and 'Attrited Customer' this means that there are no unexpected values or spelling mistakes in the 'Attrition_Flag' column

# %%
# Shows the unique values in the 'Attrition_Flag' column
df['Attrition_Flag'].unique() 
#this shows that the 'Attrition_Flag' column has two unique values: 'Existing Customer' and 'Attrited Customer'
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %% [markdown]
# The .value_counts function shows how many times each value appears in the column. It shows the count for each category.
# the output shows there are 2 entries in the column 'Existing Customer'  8,500 and 'Attrited Customer'   1627 and how many times each is listed

# %%
# Checking the value counts of the 'Attrition_Flag' column to see how many customers are existing and how many have attrited
df['Attrition_Flag'].value_counts()
# this shows that there are 8500 existing customers and 1627 attrited customers in the dataset. This means that the majority of the customers in the dataset are existing customers, while a smaller portion have attrited.
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
# Create a pie chart to visualize the distribution of customer attrition in the dataset
plt.pie(df['Attrition_Flag'].value_counts(), labels=df['Attrition_Flag'].unique(), autopct='%1.1f%%', startangle=90, colors=["#7bb5ef","#dc2a2a"])
plt.title('Customer Attrition Distribution')
plt.show()
# Out:
# Text(0.5, 1.0, 'Customer Attrition Distribution')

# %% [markdown]
# I created a pie chart with percentages to see the percentage existing and attrited customers

# %% [markdown]
# ---

# %% [markdown]
# # Section 2 Data Cleaning

# %% [markdown]
# Section 2 content i will be checking the data for any duplocates, missing values, and any inconsistencies. The data will be getting prepared to be saved as a clean dataset ready for visualisation.

# %% [markdown]
# isnull().sum is used to count the number of missing values in each column of a dataset. It helps identify which columns contain null or empty entries and shows if data cleaning is needed. It was used to check the dataset for missing values. The dataset does not have any missing values so will need to fill in any missing values.However, If missing values had been found, they would have been handled by filling them with appropriate values.

# %%
# Checking to see if there are any missing values in the dataset
df.isnull().sum()
# There are no missing values in the dataset, which is good because it means that all the data is complete and there are no gaps in the information.
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %% [markdown]
# .duplicated() is used to find duplicate rows in the dataset.This dataset does not have any duplicates but if there were duplicates, they would have been removed by using the .drop_duplicates function.

# %%
#Checking for duplicate rows in the dataset
df.duplicated().sum()
# this shows that there are no duplicate rows in the dataset, which is good because it means that each row represents a unique customer.
# Out:
# 0

# %% [markdown]
# # Dropping columns
# The .drop function drops any columns which are specified. it used to drop any columns which will not be useful in further analysis. In this case dropping the 'CLIENTNUM' colum as it is not of any use because it is just an ID coulmn. axis=1 is written to drop the column and inplace=True to overwrite from the original dataset.
# df.head() is used to check if the column has been dropped.

# %%
# i am going to drop the 'CLIENTNUM' column from the dataset because it is not relevant to the analysis and will not be used in the machine learning models. The 'CLIENTNUM' column is a unique identifier for each customer and is not going to be useful in my further analysis
df.drop('CLIENTNUM', axis=1, inplace=True)
df.head() # i will show the first 5 rows of the dataset to see the changes made to the dataset. The 'CLIENTNUM' column has been dropped from the dataset.
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %% [markdown]
# 2 further columns have been dropped as they wont be needed for data visualisation and cleans up the dataset

# %%
# Dropping 2 furth columns which are of no use in the analysis.
df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1, inplace=True)
df.head() # Checks the first 5 rows of the dataset to see the changes.
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %% [markdown]
# # Encoding categorical values
# By using the .map function is has allows you to convert text values into numbers for selected columns. It has been created beauce machine learning models cannot work with text data as it will crash the code so it has been converted into numbers. In this case, we have used the 'Attrition_Flag' column and coverted 'Existing Customer' to 0 and 'Attrited Customer' to 1.
# df.head is used to check the code has worked
# the 'Attrition_Flag' column is now ready to be used in machine learning.

# %%
#i am going to encode the categorical variables in the dataset using one-hot encoding. This will convert the categorical variables into numerical variables that can be used in machine learning models. i will be encoding the 'attrition_flag'
df['Attrition_Flag'] = df['Attrition_Flag'].map({'Existing Customer': 0, 'Attrited Customer': 1})
df.head() # i will show the first 5 rows of the dataset to see the changes made to the 'Attrition_Flag' column. The values in the 'Attrition_Flag' column have been converted from categorical values to numerical values, with 'Existing Customer' being represented as 0 and 'Attrited Customer' being represented as 1.
# Out:
#    Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0               0            45      M                3     High School
# 1               0            49      F                5        Graduate
# 2               0            51      M                3        Graduate
# 3               0            40      F                4     High School
# 4               0            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %% [markdown]
# # Saving the cleaned dataset in the cleaned data folder

# %%
df.to_csv('Dataset/CleanedData/BankChurners_cleaned.csv', index=False) # i will save the cleaned dataset to a new csv file called 'BankChurners_cleaned.csv' in the 'CleanedData' folder. The index=False parameter is used to prevent the index column from being saved to the csv file.
print('Cleaned dataset has been saved to CleanedData folder!')
# Out:
# Cleaned dataset has been saved to CleanedData folder!

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
# Out:
#   Cell In[20], line 5
#     except Exception as e:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 2
